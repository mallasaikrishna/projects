# %%
###COVID-19 DATA SET
#Q.1)Show the number of confired,Deaths and Recovery cases in each Region
#Q.2)Remove all the records where Confired cases is less than 10.
#Q.3)In which Region,maximum number of confirmed cases were recored?
#Q.4)In which Region,minimum number of Deaths cases were recored?
#Q.5)How many confirmed, Deaths & recovered cases were reported from India till 29 April 2020?

# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/ASUS/Downloads/Covid-19.csv")
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data.head(20)
# Out:
#          Date State               Region  Confirmed  Deaths  Recovered
# 0   4/29/2020   NaN          Afghanistan       1939      60        252
# 1   4/29/2020   NaN              Albania        766      30        455
# 2   4/29/2020   NaN              Algeria       3848     444       1702
# 3   4/29/2020   NaN              Andorra        743      42        423
# 4   4/29/2020   NaN               Angola         27       2          7
# 5   4/29/2020   NaN  Antigua and Barbuda         24       3         11
# 6   4/29/2020   NaN            Argentina       4285     214       1192
# 7   4/29/2020   NaN              Armenia       1932      30        900
# 8   4/29/2020   NaN              Austria      15402     580      12779
# 9   4/29/2020   NaN           Azerbaijan       1766      23       1267
# 10  4/29/2020   NaN              Bahamas         80      11         23
# 11  4/29/2020   NaN              Bahrain       2921       8       1455
# ...

# %%
#1.
#df.count()
#df.isnull().sum()

# %%
data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
#2.
#import seaborn as sns
#import matplotlib.pyplot as plt
#sns.heatmap(data.isnul))
#data.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.plot()
# Out:
# <Axes: >

# %%
#Q.1)Show the number of confired,Deaths and Recovery cases in each Region
#df.groupby("Region").sum().head(50)
#df.groupby("Region")['confirmed'].sum().sort_values(ascending = False).head(20)
#df.groupby("Region")['confirmed','Recovered'].sum()

# %%
data.groupby("Region").sum().head(20)
# Out:
#                                                                   Date  \
# Region
# Afghanistan                                                  4/29/2020
# Albania                                                      4/29/2020
# Algeria                                                      4/29/2020
# Andorra                                                      4/29/2020
# Angola                                                       4/29/2020
# Antigua and Barbuda                                          4/29/2020
# Argentina                                                    4/29/2020
# Armenia                                                      4/29/2020
# Australia            4/29/20204/29/20204/29/20204/29/20204/29/20204...
# Austria                                                      4/29/2020
# Azerbaijan                                                   4/29/2020
# Bahamas                                                      4/29/2020
# ...

# %%
data.groupby("Region")['Confirmed'].sum().sort_values(ascending = False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %%
#data.groupby("Region"),["Confirmed"]["Recovered"].sum()
data.groupby("Region")[['Confirmed','Recovered']].sum()
# Out:
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %%
#Q.2)Remove all the records where Confired cases is less than 10.
#data.Confirmed < 10
#data[data.Confirmed < 10]
#data[~(data.Confirmed < 10)]
#data = data[~Confirmed < 10)] to remove the records satisfying a particular condition

# %%
data.Confirmed < 10
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 316    False
# 317    False
# 318    False
# 319    False
# 320    False
# Name: Confirmed, Length: 321, dtype: bool

# %%
data[data.Confirmed < 10]
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 194  4/29/2020            British Virgin Islands                     UK
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 272  4/29/2020             Northwest Territories                 Canada
# ...

# %%
data[~(data.Confirmed < 10)]
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
data1 = data[~(data.Confirmed < 10)]
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
#Q.3)In which Region,maximum number of confirmed cases were recored?

# %%
data.groupby("Region").Confirmed.sum().sort_values(ascending = False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %%
#Q.4)In which Region,minimum number of Deaths cases were recored?

# %%
data.groupby("Region").Deaths.sum().sort_values(ascending = True).head(50)
# Out:
# Region
# Laos                                0
# Mongolia                            0
# Mozambique                          0
# Cambodia                            0
# Fiji                                0
# Namibia                             0
# Nepal                               0
# Madagascar                          0
# Macau                               0
# Papua New Guinea                    0
# Rwanda                              0
# Saint Kitts and Nevis               0
# Bhutan                              0
# Dominica                            0
# Central African Republic            0
# Saint Lucia                         0
# Holy See                            0
# Sao Tome and Principe               0
# Yemen                               0
# Western Sahara                      0
# Eritrea                             0
# Vietnam                             0
# Saint Vincent and the Grenadines    0
# Timor-Leste                         0
# ...

# %%
#Q.5)How many confirmed, Deaths & recovered cases were reported from India till 29 April 2020?
data[data.Region == 'India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
#Q6-A)Sort the entire data wrt No.of Confirmed cases in ascending order.

# %%
data.sort_values( by = ['Confirmed'],ascending = True).head(20)
# Out:
#           Date                             State                 Region  \
# 285  4/29/2020                         Recovered                     US
# 284  4/29/2020                         Recovered                 Canada
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 305  4/29/2020                             Tibet         Mainland China
# 289  4/29/2020         Saint Pierre and Miquelon                 France
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 272  4/29/2020             Northwest Territories                 Canada
# 288  4/29/2020                  Saint Barthelemy                 France
# 178  4/29/2020                               NaN                  Yemen
# 194  4/29/2020            British Virgin Islands                     UK
# 177  4/29/2020                               NaN         Western Sahara
# ...

# %%
#Q.6-B)Sort the entier data wrt no.of recovered cases in desending order.

# %%
data.sort_values( by = ['Recovered'],ascending = False) .head(20)
# Out:
#           Date      State          Region  Confirmed  Deaths  Recovered
# 153  4/29/2020        NaN           Spain     236899   24275     132929
# 285  4/29/2020  Recovered              US          0       0     120720
# 61   4/29/2020        NaN         Germany     161539    6467     120400
# 76   4/29/2020        NaN            Iran      93657    5957      73791
# 80   4/29/2020        NaN           Italy     203591   27682      71252
# 229  4/29/2020      Hubei  Mainland China      68128    4512      63616
# 57   4/29/2020        NaN          France     165093   24087      48228
# 167  4/29/2020        NaN          Turkey     117589    3081      44040
# 22   4/29/2020        NaN          Brazil      79685    5513      34132
# 158  4/29/2020        NaN     Switzerland      29407    1716      22600
# 284  4/29/2020  Recovered          Canada          0       0      20327
# 78   4/29/2020        NaN         Ireland      20253    1190      13386
# ...
